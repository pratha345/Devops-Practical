# %% [markdown]
# <a href="https://colab.research.google.com/github/pratha345/Devops-Practical/blob/main/23_MACHINE_LEARNING_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
Orgcredit_card_data = credit_card_data
credit_card_data
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 47623  43281 -0.696585  1.108944  1.413769 -0.127104  0.018555 -0.455078
# 47624  43282 -0.282262 -1.212401  2.174897 -0.181501 -1.604027 -0.332694
# 47625  43282 -1.513495 -0.206282 -0.702405  1.056423  1.058711 -0.708973
# 47626  43282 -0.659193  1.270953  0.946464 -0.370180  1.619207 -0.288297
# 47627  43282  1.121749 -0.208202  0.660816  0.857988 -0.823614 -0.422509
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
credit_card_data.shape
# Out:
# (47628, 31)

# %%
credit_card_data.info
# Out:
# <bound method DataFrame.info of         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 47623  43281 -0.696585  1.108944  1.413769 -0.127104  0.018555 -0.455078
# 47624  43282 -0.282262 -1.212401  2.174897 -0.181501 -1.604027 -0.332694
# 47625  43282 -1.513495 -0.206282 -0.702405  1.056423  1.058711 -0.708973
# 47626  43282 -0.659193  1.270953  0.946464 -0.370180  1.619207 -0.288297
# 47627  43282  1.121749 -0.208202  0.660816  0.857988 -0.823614 -0.422509
#
# ...

# %%
credit_card_data.isnull(). sum(axis=0).sort_values(ascending=False)
# Out:
# Class     1
# Amount    1
# V28       1
# V27       1
# V26       1
# V25       1
# V24       1
# V23       1
# V22       1
# V21       1
# V20       1
# V19       1
# V18       1
# V17       1
# V16       0
# Time      0
# V1        0
# V14       0
# V13       0
# V12       0
# V11       0
# V10       0
# V9        0
# V8        0
# V7        0
# V6        0
# V5        0
# V4        0
# V3        0
# V2        0
# V15       0
# dtype: int64

# %%
credit_card_data.isnull(). sum(axis=0).sort_values(ascending=False).head(10)
# Out:
# Class     1
# Amount    1
# V28       1
# V27       1
# V26       1
# V25       1
# V24       1
# V23       1
# V22       1
# V21       1
# dtype: int64

# %%
credit_card_data.isnull().sum() > 0
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17        True
# V18        True
# V19        True
# V20        True
# V21        True
# V22        True
# V23        True
# V24        True
# V25        True
# V26        True
# V27        True
# V28        True
# Amount     True
# Class      True
# dtype: bool

# %%
d = credit_card_data.isnull() . any

# %%
d
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.any of         Time     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 47623  False  False  False  False  False  False  False  False  False  False
# 47624  False  False  False  False  False  False  False  False  False  False
# 47625  False  False  False  False  False  False  False  False  False  False
# 47626  False  False  False  False  False  False  False  False  False  False
# ...

# %%
credit_card_data.isnull().any(axis=0)
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17        True
# V18        True
# V19        True
# V20        True
# V21        True
# V22        True
# V23        True
# V24        True
# V25        True
# V26        True
# V27        True
# V28        True
# Amount     True
# Class      True
# dtype: bool

# %%
d = credit_card_data.isnull().any(axis=0)
d
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17        True
# V18        True
# V19        True
# V20        True
# V21        True
# V22        True
# V23        True
# V24        True
# V25        True
# V26        True
# V27        True
# V28        True
# Amount     True
# Class      True
# dtype: bool

# %%
index = d.index[d.values]

# %%
index
# Out:
# Index(['V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26',
#        'V27', 'V28', 'Amount', 'Class'],
#       dtype='object')

# %%
credit_card_data.isnull().all(axis=0)
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
credit_card_data.isnull().all(axis=1).sum()
# Out:
# 0

# %%
credit_card_data.isnull().sum(axis=1)==21
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 47623    False
# 47624    False
# 47625    False
# 47626    False
# 47627    False
# Length: 47628, dtype: bool

# %%
credit_card_data.isnull().sum().sort_values(ascending=False)/len(credit_card_data) * 100
# Out:
# Class     0.0021
# Amount    0.0021
# V28       0.0021
# V27       0.0021
# V26       0.0021
# V25       0.0021
# V24       0.0021
# V23       0.0021
# V22       0.0021
# V21       0.0021
# V20       0.0021
# V19       0.0021
# V18       0.0021
# V17       0.0021
# V16       0.0000
# Time      0.0000
# V1        0.0000
# V14       0.0000
# V13       0.0000
# V12       0.0000
# V11       0.0000
# V10       0.0000
# V9        0.0000
# V8        0.0000
# V7        0.0000
# V6        0.0000
# V5        0.0000
# V4        0.0000
# V3        0.0000
# V2        0.0000
# V15       0.0000
# dtype: float64

# %%
round(credit_card_data.isnull().sum().sort_values(ascending=False)/len(credit_card_data) *100,2)
# Out:
# Class     0.0
# Amount    0.0
# V28       0.0
# V27       0.0
# V26       0.0
# V25       0.0
# V24       0.0
# V23       0.0
# V22       0.0
# V21       0.0
# V20       0.0
# V19       0.0
# V18       0.0
# V17       0.0
# V16       0.0
# Time      0.0
# V1        0.0
# V14       0.0
# V13       0.0
# V12       0.0
# V11       0.0
# V10       0.0
# V9        0.0
# V8        0.0
# V7        0.0
# V6        0.0
# V5        0.0
# V4        0.0
# V3        0.0
# V2        0.0
# V15       0.0
# dtype: float64

# %%
col = credit_card_data.isnull().sum().sort_values(ascending=False).head(3).index.values

# %%
col
# Out:
# array(['Class', 'Amount', 'V28'], dtype=object)

# %%
credit_card_data = credit_card_data.drop(col,axis='columns')

# %%
credit_card_data
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 47623  43281 -0.696585  1.108944  1.413769 -0.127104  0.018555 -0.455078
# 47624  43282 -0.282262 -1.212401  2.174897 -0.181501 -1.604027 -0.332694
# 47625  43282 -1.513495 -0.206282 -0.702405  1.056423  1.058711 -0.708973
# 47626  43282 -0.659193  1.270953  0.946464 -0.370180  1.619207 -0.288297
# 47627  43282  1.121749 -0.208202  0.660816  0.857988 -0.823614 -0.422509
#
#              V7        V8        V9  ...       V18       V19       V20  \
# ...

# %%
round(credit_card_data.isnull().sum().sort_values(ascending=False)/len(credit_card_data) * 100,2)
# Out:
# V27     0.0
# V26     0.0
# V25     0.0
# V24     0.0
# V23     0.0
# V22     0.0
# V21     0.0
# V20     0.0
# V19     0.0
# V18     0.0
# V17     0.0
# V1      0.0
# V16     0.0
# V15     0.0
# Time    0.0
# V13     0.0
# V12     0.0
# V11     0.0
# V10     0.0
# V9      0.0
# V8      0.0
# V7      0.0
# V6      0.0
# V5      0.0
# V4      0.0
# V3      0.0
# V2      0.0
# V14     0.0
# dtype: float64

# %%
len(credit_card_data[credit_card_data.isnull().sum(axis=1) > 5])/len(credit_card_data)*1000000000000
# Out:
# 20996052.74208449

# %%
credit_card_data = credit_card_data[credit_card_data.isnull().sum(axis=1) <=5]

# %%
credit_card_data
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 47622  43281  1.468348 -1.140941  0.372482 -1.452282 -1.395891 -0.350258
# 47623  43281 -0.696585  1.108944  1.413769 -0.127104  0.018555 -0.455078
# 47624  43282 -0.282262 -1.212401  2.174897 -0.181501 -1.604027 -0.332694
# 47625  43282 -1.513495 -0.206282 -0.702405  1.056423  1.058711 -0.708973
# 47626  43282 -0.659193  1.270953  0.946464 -0.370180  1.619207 -0.288297
#
#              V7        V8        V9  ...       V18       V19       V20  \
# ...

# %%
credit_card_data
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 47622  43281  1.468348 -1.140941  0.372482 -1.452282 -1.395891 -0.350258
# 47623  43281 -0.696585  1.108944  1.413769 -0.127104  0.018555 -0.455078
# 47624  43282 -0.282262 -1.212401  2.174897 -0.181501 -1.604027 -0.332694
# 47625  43282 -1.513495 -0.206282 -0.702405  1.056423  1.058711 -0.708973
# 47626  43282 -0.659193  1.270953  0.946464 -0.370180  1.619207 -0.288297
#
#              V7        V8        V9  ...       V18       V19       V20  \
# ...

# %%
round(credit_card_data.isnull().sum().sort_values(ascending=False)/len(credit_card_data) *10000000,20)
# Out:
# Time    0.0
# V1      0.0
# V26     0.0
# V25     0.0
# V24     0.0
# V23     0.0
# V22     0.0
# V21     0.0
# V20     0.0
# V19     0.0
# V18     0.0
# V17     0.0
# V16     0.0
# V15     0.0
# V14     0.0
# V13     0.0
# V12     0.0
# V11     0.0
# V10     0.0
# V9      0.0
# V8      0.0
# V7      0.0
# V6      0.0
# V5      0.0
# V4      0.0
# V3      0.0
# V2      0.0
# V27     0.0
# dtype: float64

# %%
credit_card_data[~np.isnan(credit_card_data['V3'])]
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 47622  43281  1.468348 -1.140941  0.372482 -1.452282 -1.395891 -0.350258
# 47623  43281 -0.696585  1.108944  1.413769 -0.127104  0.018555 -0.455078
# 47624  43282 -0.282262 -1.212401  2.174897 -0.181501 -1.604027 -0.332694
# 47625  43282 -1.513495 -0.206282 -0.702405  1.056423  1.058711 -0.708973
# 47626  43282 -0.659193  1.270953  0.946464 -0.370180  1.619207 -0.288297
#
#              V7        V8        V9  ...       V18       V19       V20  \
# ...

# %%
round(credit_card_data.isnull().sum().sort_values(ascending=False)/len(credit_card_data) * 100,2)
# Out:
# Time    0.0
# V1      0.0
# V26     0.0
# V25     0.0
# V24     0.0
# V23     0.0
# V22     0.0
# V21     0.0
# V20     0.0
# V19     0.0
# V18     0.0
# V17     0.0
# V16     0.0
# V15     0.0
# V14     0.0
# V13     0.0
# V12     0.0
# V11     0.0
# V10     0.0
# V9      0.0
# V8      0.0
# V7      0.0
# V6      0.0
# V5      0.0
# V4      0.0
# V3      0.0
# V2      0.0
# V27     0.0
# dtype: float64

# %%
credit_card_data['V4'].describe()
# Out:
# count    47627.000000
# mean         0.191060
# std          1.402208
# min         -5.172595
# 25%         -0.714465
# 50%          0.195057
# 75%          1.070586
# max         16.491217
# Name: V4, dtype: float64

# %%
credit_card_data = credit_card_data[credit_card_data['V5'].notnull()]

# %%
credit_card_data
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 47622  43281  1.468348 -1.140941  0.372482 -1.452282 -1.395891 -0.350258
# 47623  43281 -0.696585  1.108944  1.413769 -0.127104  0.018555 -0.455078
# 47624  43282 -0.282262 -1.212401  2.174897 -0.181501 -1.604027 -0.332694
# 47625  43282 -1.513495 -0.206282 -0.702405  1.056423  1.058711 -0.708973
# 47626  43282 -0.659193  1.270953  0.946464 -0.370180  1.619207 -0.288297
#
#              V7        V8        V9  ...       V18       V19       V20  \
# ...

# %%
round(credit_card_data.isnull().sum().sort_values(ascending=False)/len(credit_card_data) *100,2)
# Out:
# Time    0.0
# V1      0.0
# V26     0.0
# V25     0.0
# V24     0.0
# V23     0.0
# V22     0.0
# V21     0.0
# V20     0.0
# V19     0.0
# V18     0.0
# V17     0.0
# V16     0.0
# V15     0.0
# V14     0.0
# V13     0.0
# V12     0.0
# V11     0.0
# V10     0.0
# V9      0.0
# V8      0.0
# V7      0.0
# V6      0.0
# V5      0.0
# V4      0.0
# V3      0.0
# V2      0.0
# V27     0.0
# dtype: float64

# %%
credit_card_data.loc[:,['V3','V4']].describe()
# Out:
#                  V3            V4
# count  47627.000000  47627.000000
# mean       0.694689      0.191060
# std        1.519910      1.402208
# min      -32.965346     -5.172595
# 25%        0.220591     -0.714465
# 50%        0.800268      0.195057
# 75%        1.432177      1.070586
# max        4.101716     16.491217

# %%
credit_card_data['V5'].mean()
# Out:
# -0.2498247999093917

# %%
credit_card_data.loc[:,'V6'].fillna(credit_card_data['V6'].mean(),inplace=True)

# %%
credit_card_data.loc[:,'V5'].fillna(credit_card_data['V5'].mean(),inplace=True)

# %%
round(credit_card_data.isnull().sum().sort_values(ascending=False)/len(credit_card_data) * 100,2)
# Out:
# Time    0.0
# V1      0.0
# V26     0.0
# V25     0.0
# V24     0.0
# V23     0.0
# V22     0.0
# V21     0.0
# V20     0.0
# V19     0.0
# V18     0.0
# V17     0.0
# V16     0.0
# V15     0.0
# V14     0.0
# V13     0.0
# V12     0.0
# V11     0.0
# V10     0.0
# V9      0.0
# V8      0.0
# V7      0.0
# V6      0.0
# V5      0.0
# V4      0.0
# V3      0.0
# V2      0.0
# V27     0.0
# dtype: float64

# %%
credit_card_data.loc[:,['V7','V8']].describe()
# Out:
#                  V7            V8
# count  47627.000000  47627.000000
# mean      -0.119863      0.053449
# std        1.282115      1.216943
# min      -26.548144    -41.484823
# 25%       -0.602244     -0.146951
# 50%       -0.074940      0.057085
# 75%        0.425897      0.329624
# max       36.677268     20.007208

# %%
credit_card_data.groupby('V3').V3.count().sort_values(ascending=False)
# Out:
# V3
# -0.495757    36
# -0.083297    28
#  1.857002    24
# -0.551952    23
# -0.061407    19
#              ..
#  0.441486     1
#  0.441497     1
#  0.441523     1
#  0.441527     1
#  4.101716     1
# Name: V3, Length: 46570, dtype: int64

# %%
credit_card_data['V1'].astype('V2').value_counts()
# Out:
# b'.7'          37
# b'\xd6\xf6'    28
# b'\xc4\xd4'    25
# b'\xcc\xbc'    25
# b'\x8d\xb8'    20
#                ..
# b'9P'           1
# b'v\xd8'        1
# b'\xeb\xc4'     1
# b'V\x11'        1
# b'\x10\xe9'     1
# Name: V1, Length: 33253, dtype: int64

# %%
credit_card_data.loc[:,'V7'].fillna(2,inplace=True)

# %%
round(credit_card_data.isnull().sum().sort_values(ascending=False)/len(credit_card_data) * 100,2)
# Out:
# Time    0.0
# V1      0.0
# V26     0.0
# V25     0.0
# V24     0.0
# V23     0.0
# V22     0.0
# V21     0.0
# V20     0.0
# V19     0.0
# V18     0.0
# V17     0.0
# V16     0.0
# V15     0.0
# V14     0.0
# V13     0.0
# V12     0.0
# V11     0.0
# V10     0.0
# V9      0.0
# V8      0.0
# V7      0.0
# V6      0.0
# V5      0.0
# V4      0.0
# V3      0.0
# V2      0.0
# V27     0.0
# dtype: float64

# %%
len(credit_card_data/len(Orgcredit_card_data) * 100000)
# Out:
# 47627
